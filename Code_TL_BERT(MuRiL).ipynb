# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install spacy
# !pip install contractions
# !pip install emoji
# !pip install emot
# !pip install demoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 1.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import spacy
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
import string
import contractions
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import re
from nltk.tokenize import TweetTokenizer
import emoji
import regex
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
import demoji
import emoji
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
demoji.download_codes()
# Out:
# <ipython-input-4-b6fe2259445e>:1: FutureWarning: The demoji.download_codes attribute is deprecated and will be removed from demoji in a future version. It is an unused attribute as emoji codes are now distributed directly with the demoji package.
#   demoji.download_codes()

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('whitespace')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Error loading whitespace: Package 'whitespace' not found
# [nltk_data]     in index
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import ComplementNB
from sklearn.pipeline import Pipeline
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline

# %%
# !pip install tensorflow
# !pip install tensorflow-text
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 110.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 43.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 92.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
# ...

# %% [markdown]
# **Reading Dataset**

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Fake_News/Task1/Fake_train.csv')
df_val=pd.read_csv('/content/drive/MyDrive/Fake_News/Task1/Fake_dev.csv')
df_test= pd.read_csv('/content/drive/MyDrive/Fake_News/Task1/Fake_test_without_labels.csv')

# %%
# df_train['text'] = df_train['title'].fillna(" ") + " "+df_train['text']
# df_val['text'] = df_val['title'].fillna(" ") + df_val['text']

# %%
text= df_train['text']

# %% [markdown]
# **Preprocess**

# %%
#emot_object = emot.core.emot()
import re
ps =PorterStemmer()
lemmatiser = WordNetLemmatizer()
english_stopwords = stopwords.words('english')
exclude = set(string.punctuation)

def preprocess(text):
  #text=demoji.findall(df['Text'])
  text = contractions.fix(text.lower(), slang=True)
  text =re.sub("@ ?[A-Za-z0-9_]+", "", text)
  text= re.sub(r'\d+', '', text)
  text=re.sub(r'$', '', text)
  text= re.sub(r'’','', text )
  text=re.sub('<.*?>','',text)
  text=re.sub(r'http\S+', '', text)
  #text=emoji.demojize(text, delimiters=(" ", " "))
  text = ''.join(ch for ch in text if ch not in exclude)
  tokens = word_tokenize(text)
  #print("Tokens:", tokens)
  text = [t for t in tokens if t not in english_stopwords]
  text = " ".join(text)
  return text

# %%
#EXTRA PREPROCESSING CODE
import pandas as pd
import re
# from indicnlp.tokenize import indic_tokenize

def preprocess_code_mixed_text(text):
    english_pattern = r'[a-zA-Z]+'
    malayalam_pattern = r'[ം-ഃ അ-ഹ ാ-് ൦-൯]+'

    english_segments = re.findall(english_pattern, text)
    malayalam_segments = re.findall(malayalam_pattern, text)

    processed_english_segments = [segment.lower() for segment in english_segments]

    processed_malayalam_segments = []
    for segment in malayalam_segments:
        tokens = indic_tokenize.trivial_tokenize(segment)
        processed_malayalam_segments.append(' '.join(tokens))

    processed_text = ' '.join(processed_english_segments + processed_malayalam_segments)

    return processed_text

# %%
import emoji
#import demoji
#demoji.download_codes()
def emo(text):
  temp=emoji.demojize(text,delimiters=(" "," "))
  temp=temp.replace("_","  ")
  return temp

# %%
df_train['clean_text']=df_train["text"].apply(lambda x:emo(x))
df_train["clean_text"]=df_train['clean_text'].apply(lambda X: preprocess(X))
df_train["clean_text"]
# Out:
# 0                        നല്ല അവതരണം സത്യം പുറത്തു വരട്ടെ
# 1                                             masha allah
# 2       അന്വേഷണം കഴിയുമ്പോൾ c യ്ക്ക് എതിരായ കലാപം പോലെ...
# 3         illathentha avaru purath vidayittalland verenth
# 4       barana pakshathin matoru niyamamnalla moyanth ...
#                               ...
# 3252    വീണാ ജോർജ് എന്ന ഒരു ആരോഗ്യ മന്ത്രി വന്നതിനു ശേ...
# 3253    ഇതാണ് പിണുവാതിര face tears joy face tears joy ...
# 3254                  കേസ് എടുക്കണം hundred points thumbs
# 3255            എല്ലാത്തിനേം സോപ്പിട്ട് കളിപ്പിച്ച് വിടണം
# 3256    day day leaders r acting like fool devils country
# Name: clean_text, Length: 3257, dtype: object

# %%
df_val['clean_text']=df_val["text"].apply(lambda x:emo(x))
df_val["clean_text"]=df_val['clean_text'].apply(lambda X: preprocess(X))
df_val["clean_text"]
# Out:
# 0                                  full musilm verodamum
# 1      പക്ഷികളും മൃഗങ്ങളും ഈ ലോകത്ത് സുഖമായി ജീവിക്കു...
# 2      ഒരു താടിക്കാരൻ പാത്രം കൊട്ടാൻ പറഞ്ഞപ്പോ മറ്റൊര...
# 3                                          കുംഭളേമമറന്നോ
# 4      ഇത് തിരുവാതിര അല്ല കോറോണയെ കൈകൊട്ടി കൊല്ലുകയാണ...
#                              ...
# 810                  ജനങ്ങൾ വിഡ്ഢികളല്ല അത്രേ പറയാനുള്ളു
# 811            face tears joy face tears joy ഒരു പിണറായി
# 812    mr sir know bodhidarma great sindha english do...
# 813                           ബുദ്ധിയുള്ളവരെ വിജയിപ്പിക്
# 814                 വേണ്ടാത്ത പരിപാടിയിപ്പോയി എന്തായാലും
# Name: clean_text, Length: 815, dtype: object

# %%
df_test['clean_text']=df_test["text"].apply(lambda x:emo(x))
df_test["clean_text"]=df_test['clean_text'].apply(lambda X: preprocess(X))
df_test["clean_text"]
# Out:
# 0                 ഉള്ള പോൾ ലോഗ്‌ഡ്‌വൻ ഇപ്പോള് എന്താ കാരണം
# 1       ഓഷോ രജനീഷ് പറഞ്ഞപോലെ എനിക്കപ്പോൾ തോന്നിയത് അങ്...
# 2       ചേട്ടാ വാർത്ത വയ്ക്കുന്നത് കേരളത്തിലാണ് സംഘി ഭ...
# 3                                      shame entire woman
# 4       code janaghal andhu wide business cheythalum v...
#                               ...
# 1014         correct china cheitha weapon spread ing aanu
# 1015    ഈ പറയുന്നതനുസരിച്ചു ചികിത്സയും ലോക്ക് ഡൌൺ മണ്ട...
# 1016         mask illa aarkum smirking face smirking face
# 1017             ഇയാളെ കൊറോണ രോഗി കൾ കിടയിൽ ഇടാമായിരുന്നു
# 1018    kulathrikalkku badilayialavilathikal keralum n...
# Name: clean_text, Length: 1019, dtype: object

# %%
new_cols = ["clean_text","label"]
df_train=df_train[new_cols]

# %%
df_train
# Out:
#                                              clean_text     label
# 0                      നല്ല അവതരണം സത്യം പുറത്തു വരട്ടെ      Fake
# 1                                           masha allah      Fake
# 2     അന്വേഷണം കഴിയുമ്പോൾ c യ്ക്ക് എതിരായ കലാപം പോലെ...      Fake
# 3       illathentha avaru purath vidayittalland verenth      Fake
# 4     barana pakshathin matoru niyamamnalla moyanth ...  original
# ...                                                 ...       ...
# 3252  വീണാ ജോർജ് എന്ന ഒരു ആരോഗ്യ മന്ത്രി വന്നതിനു ശേ...  original
# 3253  ഇതാണ് പിണുവാതിര face tears joy face tears joy ...  original
# 3254                കേസ് എടുക്കണം hundred points thumbs  original
# 3255          എല്ലാത്തിനേം സോപ്പിട്ട് കളിപ്പിച്ച് വിടണം  original
# 3256  day day leaders r acting like fool devils country  original
#
# [3257 rows x 2 columns]

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df_train['label']= label_encoder.fit_transform(df_train['label'])

df_train['label'].unique()
# Out:
# array([0, 1])

# %%
df_train
# Out:
#                                              clean_text  label
# 0                      നല്ല അവതരണം സത്യം പുറത്തു വരട്ടെ      0
# 1                                           masha allah      0
# 2     അന്വേഷണം കഴിയുമ്പോൾ c യ്ക്ക് എതിരായ കലാപം പോലെ...      0
# 3       illathentha avaru purath vidayittalland verenth      0
# 4     barana pakshathin matoru niyamamnalla moyanth ...      1
# ...                                                 ...    ...
# 3252  വീണാ ജോർജ് എന്ന ഒരു ആരോഗ്യ മന്ത്രി വന്നതിനു ശേ...      1
# 3253  ഇതാണ് പിണുവാതിര face tears joy face tears joy ...      1
# 3254                കേസ് എടുക്കണം hundred points thumbs      1
# 3255          എല്ലാത്തിനേം സോപ്പിട്ട് കളിപ്പിച്ച് വിടണം      1
# 3256  day day leaders r acting like fool devils country      1
#
# [3257 rows x 2 columns]

# %% [markdown]
# **Model Building :** Bert embedding+ classifier Construction : Pretrained Model

# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 27.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 73.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 123.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 30.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 40.3 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers

# %%
pip install --upgrade transformers

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs

# %% [markdown]
# Bert Models from Hugging Face
# https://huggingface.co/

# %%
model = ClassificationModel('bert', 'google/muril-base-cased', num_labels=2, args={'reprocess_input_data': True, 'overwrite_output_dir': True})
#jy46604790/Fake-News-Bert-Detect
#hamzab/roberta-fake-news-classification
#XSY/albert-base-v2-fakenews-discriminator
#MYC007/Real-and-Fake-News-Detection



# bert-base-multilingual-cased
#          precision    recall  f1-score   support

#         Fake       0.84      0.83      0.83       406
#     original       0.83      0.85      0.84       409

#     accuracy                           0.84       815
#    macro avg       0.84      0.84      0.84       815
# weighted avg       0.84      0.84      0.84       815





# sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2

#        precision    recall  f1-score   support

#         Fake       0.86      0.84      0.85       406
#     original       0.84      0.86      0.85       409

#     accuracy                           0.85       815
#    macro avg       0.85      0.85      0.85       815
# weighted avg       0.85      0.85      0.85       815


#google/muril-base-cased without Rchar


# precision    recall  f1-score   support

#         Fake       0.87      0.81      0.84       406
#     original       0.82      0.88      0.85       409

#     accuracy                           0.84       815
#    macro avg       0.84      0.84      0.84       815
# weighted avg       0.84      0.84      0.84       815
# Out:
# config.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/953M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google/muril-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/206 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/3.16M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/113 [00:00<?, ?B/s]

# %%
model.train_model(df_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:612: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# ...
# Running Epoch 0 of 1:   0%|          | 0/408 [00:00<?, ?it/s]
# (408, 0.5626981772628485)

# %%
list_text = []
for text in df_val['clean_text']:
  list_text.append(text)

# %%
prediction_val, raw_outputs = model.predict(list_text)
# Out:
# ...
#   0%|          | 0/102 [00:00<?, ?it/s]

# %%
val_p = label_encoder.inverse_transform(prediction_val)

# %%
val_p
# Out:
# array(['Fake', 'Fake', 'original', 'original', 'original', 'Fake',
#        'original', 'original', 'original', 'Fake', 'Fake', 'original',
#        'Fake', 'Fake', 'Fake', 'original', 'original', 'Fake', 'original',
#        'Fake', 'original', 'original', 'original', 'Fake', 'original',
#        'original', 'Fake', 'Fake', 'original', 'original', 'Fake',
#        'original', 'original', 'Fake', 'original', 'Fake', 'original',
#        'original', 'original', 'Fake', 'Fake', 'original', 'original',
#        'Fake', 'Fake', 'Fake', 'original', 'Fake', 'Fake', 'Fake', 'Fake',
#        'original', 'original', 'Fake', 'original', 'original', 'original',
#        'original', 'original', 'original', 'original', 'Fake', 'original',
#        'original', 'original', 'Fake', 'original', 'original', 'Fake',
#        'Fake', 'original', 'original', 'original', 'Fake', 'Fake', 'Fake',
#        'original', 'Fake', 'original', 'Fake', 'original', 'original',
# ...

# %%
print(classification_report(df_val['label'],val_p))
# Out:
#               precision    recall  f1-score   support
#
#         Fake       0.91      0.79      0.85       406
#     original       0.81      0.93      0.87       409
#
#     accuracy                           0.86       815
#    macro avg       0.86      0.86      0.86       815
# weighted avg       0.86      0.86      0.86       815

# %%
list_text_test = []
for text in df_test['clean_text']:
  list_text_test.append(text)

# %%
prediction_test, raw_outputs = model.predict(list_text_test)
# Out:
# ...
#   0%|          | 0/128 [00:00<?, ?it/s]

# %%
test_pred=label_encoder.inverse_transform(prediction_test)

# %%
test_pred
# Out:
# array(['original', 'original', 'Fake', ..., 'original', 'Fake',
#        'original'], dtype=object)

# %%
len(test_pred)
# Out:
# 1019
